# %% [markdown]
# # Build a corrective RAG legal assistant using OpenAI and Tavily

# %% [markdown]
# [Large Language Models](https://www.ibm.com/think/topics/large-language-models) (LLMs) are incredibly powerful, but their knowledge is limited to their training [datasets](https://www.ibm.com/think/topics/dataset). When answering questions, especially about specific, evolving, or proprietary information, LLMs can hallucinate or provide general, irrelevant answers. [Retrieval Augmented Generation](https://www.ibm.com/think/topics/retrieval-augmented-generation) (RAG) helps by giving the LLM relevant retrieved information from external data sources.
#
# However, not all RAG is created equal. Corrective Retrieval Augmented Generation (cRAG) does not simply build on top of the more traditional RAG, it represents a significant improvement. It's devised to be more robust by evaluating the quality and relevance of the retrieved results. If the context is weak, irrelevant, or from an untrustworthy source, cRAG attempts to find better information through corrective actions or, explicitly refuse to answer rather than fabricating a response. This makes cRAG systems more reliable and trustworthy for critical applications like answering legal questions.
#
# This notebook represents how to build a robust Corrective RAG (cRAG) system using OpenAI models (e.g., [GPT](https://www.ibm.com/think/topics/gpt) models like [ChatGPT](https://www.ibm.com/think/topics/chatgpt)) and LangChain. Similar frameworks like [LlamaIndex](https://www.ibm.com/think/topics/llamaindex) or [LangGraph](https://www.ibm.com/think/topics/langgraph) can also be used for building complex RAG flows with distinct nodes. Techniques like [fine-tuning](https://www.ibm.com/think/topics/fine-tuning) can further enhance specific LLM performance for domain-specific RAG.
#
# Here, we'll focus on a use case: answering questions about a specific legal document (a PDF such as a regulation, contract, or statute). This tutorial will guide you in implementing a sophisticated RAG algorithm that:
#
# - [Retrieves information](https://www.ibm.com/think/topics/information-retrieval) from your own legal PDF document.
#
# - If the internal documents are not sufficient for generating the answer, the agent can use an external web search (Tavily) as a fallback.
#
# - The agent intelligently filters out irrelevant external results so the answers stay grounded in the specific legal document at hand.
#
# - The agent will give clear, limited responses, with partial information when available, or a clear refusal where context is missing.
#
# > **Disclaimer:** This notebook is for educational and informational purposes only. It does not constitute legal advice, and outputs from the system should not be relied upon as a substitute for consultation with a qualified attorney.

# %% [markdown]
# ## Use case: building a reliable legal assistant query agent

# %% [markdown]
# This tutorial is a demonstration of creating a legal assistant query agent designed to analyze legal documents (such as a regulation, statute, or contract PDF) and answer user queries accurately. We use OpenAI models and LangChain to build the agent with robust retrieval and verification steps ensuring high-quality, source-constrained answers.
#
# Let's understand how the key principles of reliable RAG apply in our use case.
#
# ### Application of key principles
#
# **Internal knowledge base (PDF):** The agent's primary source of truth is your provided legal PDF document. It converts this document into a searchable vector store.
#
# **External search fallback (Tavily):** If the internal knowledge base doesn't have enough information, the agent can consult external web sources via Tavily. Tavily is a search engine built specifically for AI agents and LLMs, which results in a faster and real-time retrieval via its API for RAG based applications.
#
# **Context scoring:** The LLM-based retrieval evaluator (acting as a grader) will provide a score to the relevance of the items retrieved from your internal PDF while ensuring that only high quality retrieved items are included.
#
# **Query rewriting:** For web searches, the agent can rephrase the user's query to improve the chances of finding relevant external information.
#
# **Source verification:** An LLM-powered check evaluates whether external web search results are actually relevant to the legal document in question, filtering out unrelated jurisdictions, blog opinions, marketing pages, or off-topic legal commentary. This prevents the generation of misleading answers and enables self-correction, aiding in knowledge refinement.
#
# **Constrained generation:** The final prompt to the LLM strictly instructs it to use only the provided context, offer exact answers, state when information is unavailable, or provide partial answers with explicit limitations. This enhances the adaptability and reliability of the generated responses — an especially important property in the legal domain.

# %% [markdown]
# ## Prerequisites
#
# You need an [OpenAI account](https://platform.openai.com/signup) to obtain an OpenAI API key for accessing the GPT models. You will also need an [API](https://www.ibm.com/think/topics/api) key for Tavily AI for web search capabilities.
#
# ## Steps
#
# ### Step 1. Set up your environment
#
# While you can choose from several tools, this tutorial walks you through how to set up the project locally by using a Jupyter Notebook.
#
# 1. Sign in to the [OpenAI platform](https://platform.openai.com/) and generate an API key from the [API keys page](https://platform.openai.com/api-keys).
# 2. Make sure your account has access to the chat completion models you plan to use (for example, `gpt-4o-mini` or `gpt-4o`).
# 3. Create a [Jupyter Notebook](https://docs.jupyter.org/en/latest/running.html) locally or in your preferred environment.
#
# This step opens a notebook environment where you can copy the code from this tutorial. Alternatively, you can download this notebook to your local system and run it directly.

# %% [markdown]
# ### Step 2. Set up your OpenAI API key
#
# 1. Sign in to the [OpenAI platform](https://platform.openai.com/) with your account.
# 2. Navigate to the [API keys page](https://platform.openai.com/api-keys) and click "Create new secret key".
# 3. Copy the generated key and store it securely. You will need it to authenticate API calls from this notebook.
# 4. Make sure your account has sufficient credits or an active billing plan to call the chat completion models.

# %% [markdown]
# ### Step 3. Installation of the packages
#
# To work with the LangChain framework and integrate OpenAI models, we need to install some essential libraries. Let’s start by installing the required packages. This includes `langchain` for the RAG framework, `langchain-openai` for the OpenAI integration, `faiss-cpu` for efficient vector storage, `PyPDF2` for processing PDFs, `sentence-transformers` for getting an [embedding](https://www.ibm.com/think/topics/embedding), and `requests` for web API calls. These libraries are critical to applying [machine learning](https://www.ibm.com/think/topics/machine-learning) and NLP solutions.

# %%
# Install Libraries
# !pip install langchain langchain-openai langchain-community langchain-text-splitters faiss-cpu PyPDF2 sentence-transformers requests python-dotenv tavily-python
# Out:
# Requirement already satisfied: langchain in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (1.2.15)
# Requirement already satisfied: langchain-openai in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: langchain-community in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: langchain-text-splitters in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: faiss-cpu in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (1.13.2)
# Requirement already satisfied: PyPDF2 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (5.4.1)
# Requirement already satisfied: requests in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (2.33.1)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: tavily-python in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (0.7.23)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain) (1.3.2)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain) (1.1.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.0.11)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.32)
# Requirement already satisfied: packaging>=23.2.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.27.2)
# Requirement already satisfied: orjson>=3.11.5 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-openai) (2.30.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from requests) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from requests) (2.6.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from sentence-transformers) (5.5.4)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from sentence-transformers) (1.11.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.28.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.4.3)
# Requirement already satisfied: joblib>=1.3.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/agentic_ai/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)

# %% [markdown]
# **Note:** No GPU is required, but execution can be slower on CPU-based systems. This step opens a notebook environment where you can copy the code from this tutorial. This tutorial is also available on GitHub.

# %% [markdown]
# ### Step 4. Import required libraries
#
# Next, import all the required modules and securely provide your API keys for OpenAI and Tavily.

# %%
# Import required libraries

import os
import io
from dotenv import load_dotenv
from tavily import TavilyClient
from PyPDF2 import PdfReader
from langchain_openai import ChatOpenAI
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_core.prompts import PromptTemplate
from langchain_core.tools import BaseTool
import requests

# Load API keys from .env (expects OPENAI_API_KEY and TAVILY_API_KEY)
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")

if not OPENAI_API_KEY:
    raise RuntimeError("OPENAI_API_KEY is missing from your .env file")
if not TAVILY_API_KEY:
    raise RuntimeError("TAVILY_API_KEY is missing from your .env file")

# Re-export so libraries that read from the environment (e.g. ChatOpenAI) pick it up
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
os.environ["TAVILY_API_KEY"] = TAVILY_API_KEY

tavily_client = TavilyClient(api_key=TAVILY_API_KEY)

print("Credentials loaded.")
# Out:
# Credentials loaded.

# %% [markdown]
# `os:` helps to work with the operating system.
#
# `io:` allows for working with streams of data.
#
#
# `PyPDF2.PdfReader:` allows for content extraction from PDFs.
#
# `langchain_openai.ChatOpenAI:` allows us to use OpenAI chat models (e.g., GPT-4o) easily within the LangChain framework.
#
# `langchain_community.embeddings.HuggingFaceEmbeddings:` takes a HuggingFace model and generates the textual embeddings, which is important for semantic search.
#
# `langchain_community.vectorstores.FAISS:` a library for efficient vector storage and similarity search and allows us to build a vector index and and query it.
#
# `langchain_text_splitters.RecursiveCharacterTextSplitter:` helps split large constituents of text into smaller chunks, which are needed to process documents that would not otherwise fit into memory.
#
# `langchain_core.documents.Document:` represents an arbitrary unit of text with associated metadata, thus it is a building block in langchain.
#
# `langchain_core.prompts.PromptTemplate:` offers a way to create reusable, structured prompts for language models.
#
# `langchain_core.tools.BaseTool:` the base class from which you build custom tools that can be given to LangChain agents for use.
#
# `requests:` used for making HTTP requests externally to APIs.
#
# This step sets up all the tools and modules that we need to process text, create embeddings, store them in a vector database and interact with the OpenAI LLM. This step will establish all the parts needed to create a real-world RAG system, capable of sourcing, querying and searching a range of data types.

# %% [markdown]
# ### Step 5. Load and process the PDF from a local file
#
# In this step we will load the legal document PDF from a local file path. The code reads the PDF, extracts the text content and splits the text into smaller and manageable chunks. These chunks are converted into numerical embeddings and stored in a FAISS vector store, which prepares us for semantic similarity search later in local context to optimize retrieval results.
#
# For this tutorial, we use the official **EU General Data Protection Regulation (GDPR)** PDF as our example legal document. It is a substantial, real-world piece of legislation that's freely available and well suited for question-answering demos.
#
# Download it from the EU's official EUR-Lex portal and save it as `legal_document.pdf` in the same folder as this notebook:
#
# [Download GDPR (Regulation (EU) 2016/679) — Official PDF from EUR-Lex](https://eur-lex.europa.eu/legal-content/EN/TXT/PDF/?uri=CELEX:32016R0679)
#
# You can also swap in any other legal PDF you prefer (e.g. a contract, an NDA, a court opinion, the U.S. Constitution from the [National Archives](https://www.archives.gov/files/founding-docs/constitution.pdf), or a public-domain statute) by updating the `PDF_PATH` variable below.

# %%
# Path to your legal document PDF on disk.
# Update this to point to your own PDF file.
PDF_PATH = "legal_document.pdf"

with open(PDF_PATH, "rb") as f:
    pdf_bytes = io.BytesIO(f.read())

print(f" Loaded PDF from: {PDF_PATH}")

# %%
reader = PdfReader(pdf_bytes)
text = ""
for page in reader.pages:
    extracted = page.extract_text()
    if extracted:
        text += extracted

print(f" Extracted {len(text)} characters from PDF.")

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_text(text)
print(f" Split into {len(chunks)} chunks.")

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = FAISS.from_texts(chunks, embeddings)

print(f" Created FAISS index.")

# %% [markdown]
# `PDF_PATH:` the local path to your legal document PDF file. Update this to point to your own file (e.g., a regulation, contract, statute, or court opinion).
#
# `open(PDF_PATH, "rb"):` opens the PDF file in binary read mode so we can pass its raw bytes to `PdfReader`.
#
# `io.BytesIO:` wraps the PDF raw bytes into an in-memory binary stream in a format that can be utilized by `PdfReader`.
#
# `PdfReader:` creates an object that can parse and extract text from the PDF.
#
# `page.extract_text():` extracts the text of a single page in the PDF.
#
# `RecursiveCharacterTextSplitter:` configured to split the extracted text into chunks of 500 characters with an overlap of 50 characters, therefore keeping everything in context.
#
# `splitter.split_text(text):` runs the splitting of all pages of the PDF text into the smaller chunks.
#
# `HuggingFaceEmbeddings:` loads a sentence transformer model that has been pre-trained to convert the text chunks into dense vector representations.
#
# `FAISS.from_texts(chunks, embeddings):` builds an in-memory FAISS index that enables chunks of text to be searchable by their semantic similarities.
#
# This step handles full ingestion of a PDF document from disk to LLM-ready text and comfortable indexing for real-time retrieval.

# %% [markdown]
# ### Step 6. Initialize LLM and tools
#
# In this step, you'll configure the OpenAI LLM to drive your agent's reasoning, and integrate it with the Tavily web search function. The parameters of the LLM are set up for factual, stable responses.

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=OPENAI_API_KEY,
    max_tokens=300,   # ~2-3 paragraphs, good for corrective RAG
    temperature=0.2,  # low temperature = more factual, stable answers
)

print(" OpenAI LLM ready.")

# %%
class TavilySearch(BaseTool):
    name: str = "tavily_search"
    description: str = "Search the web using Tavily for extra info."

    def _run(self, query: str):
        response = requests.post(
            "https://api.tavily.com/search",
            json={"api_key": TAVILY_API_KEY, "query": query}
        )
        response.raise_for_status()
        return response.json()['results'][0]['content']


tavily_tool = TavilySearch()

# %% [markdown]
# `ChatOpenAI:` instantiates the LangChain wrapper for OpenAI chat models, allowing interaction with GPT models.
#
# `model="gpt-4o-mini":` an OpenAI chat model that is cost-effective and well-suited for instruction-following and reasoning tasks. You can swap this for other OpenAI chat models (e.g., `gpt-4o`, `gpt-4-turbo`) depending on your quality and budget needs.
#
# `class TavilySearch(BaseTool):` defines a custom LangChain tool for performing web searches using the Tavily API.
#
# `tavily_tool = TavilySearch():` creates an executable instance of the custom Tavily search tool.
#
# When we initialize `ChatOpenAI`, the `api_key` value from our previously set up credentials is passed, in order to authenticate and connect to the service. Its parameters, such as `max_tokens=300`, limit the response length, and `temperature=0.2` controls output creativity, favoring more deterministic results.
#
# The `TavilySearch` class definition includes a description of its function. It's logic is contained within the `def _run(self, query: str)` method. In this method we make an HTTP POST request to the Tavily API endpoint, including the `TAVILY_API_KEY` and the search query in the JSON payload. We then verify if there  is any HTTP errors with `response.raise_for_status()` and parse the JSON response to access the content snippet from the first search result.
#
# This step sets up the language model for text generation, and includes an external web search tool as way to augment the language model knowledge.

# %% [markdown]
# ### Step 7. Define prompt templates and helper functions
#
# This step defines the various prompt templates that guide the LLM's behavior at different stages of the RAG process. This includes prompts for scoring the relevance of internal document chunks, rewriting user queries for better web search, and a critical new prompt for verifying the source of web search results. Helper functions for scoring chunks and retrieving from the vector store are also defined.

# %%
# Define Prompt Templates and Helper Functions

# Prompt for scoring the relevance of retrieved chunks
scoring_prompt_template = PromptTemplate.from_template(
    """
You are an evaluator. Score the relevance of the context chunk to the given legal question.

Question: "{query}"

Context:
\"\"\"
{chunk}
\"\"\"

Respond only in this format:
Score: <0-5>
Reason: <one line reason>
"""
)

# Prompt for rewriting the user's query for better web search results
rewrite_prompt_template = PromptTemplate.from_template(
    """
You are a helpful assistant. Improve the following question to be clearer for a legal information search.
Focus on making the query more specific by including relevant legal terms, the name of the
statute / regulation / contract, jurisdiction, or article/section numbers when possible.

Original Question: "{query}"

Rewrite it to be clearer:
"""
)

# NEW: Prompt for verifying if Tavily context is from a relevant legal source
CONTEXT_SOURCE_VERIFICATION_PROMPT = PromptTemplate.from_template(
    """
You are an expert at identifying whether a piece of text comes from a credible, on-topic legal source
(e.g., the actual text of a statute, regulation, treaty, contract, court opinion, or commentary from
a reputable legal publisher / government body) versus an unrelated, low-quality, or off-topic source
(e.g., marketing pages, generic blog posts, unrelated jurisdictions, or content that has nothing to do
with the specific legal document the user is asking about).

If the context appears to be off-topic, from an unrelated jurisdiction, primarily promotional, or too
generic to reliably answer a specific legal question, respond with "NO".
Otherwise (if it appears to be on-topic legal content that could plausibly help answer the user's
question about the legal document at hand), respond with "YES".

Context:
\"\"\"
{context}
\"\"\"

Response:
"""
)


# Function to score chunks using the LLM
def score_chunks(chunks, query):
    scored = []
    for chunk in chunks:
        prompt = scoring_prompt_template.format(query=query, chunk=chunk)
        response = llm.invoke(prompt).content.strip()

        try:
            # Extract score using more robust parsing
            score_line = [line for line in response.splitlines() if "Score:" in line]
            if score_line:
                score = int(score_line[0].replace("Score:", "").strip())
            else:
                score = 0 # Default to 0 if score line not found
        except Exception as e:
            print(f" Could not parse score for chunk: {e}. Response: {response[:50]}...")
            score = 0 # Default to 0 on error

        scored.append((chunk, score))
    return scored

# Function to retrieve documents from FAISS vector store
def retrieve_from_vectorstore(query):
    # Retrieve top 8 similar documents from your PDF content
    docs = vectorstore.similarity_search(query, k=8)
    return [doc.page_content for doc in docs]

print(" Prompt templates and helper functions defined.")

# %% [markdown]
# `PromptTemplate.from_template:` a utility function from LangChain to create a reusable template for constructing prompts.
#
# `scoring_prompt_template:` defines a prompt that instructs the LLM to act as an evaluator and assign a relevance score (0-5) to a given context chunk based on a legal question.
#
# `rewrite_prompt_template:` defines a prompt that guides the LLM to improve or make a user's original question clearer for searching, encouraging it to add legal terms, statute names, or article/section references.
#
# `CONTEXT_SOURCE_VERIFICATION_PROMPT:` defines a prompt that instructs the LLM to verify if a piece of text (for example, from web search) is from a credible, on-topic legal source rather than unrelated marketing content, blog posts, or off-topic legal commentary.
#
# `def score_chunks(chunks, query):` defines a function that takes a list of text chunks and a query, then uses the LLM to score the relevance of each chunk.
#
# `def retrieve_from_vectorstore(query):` defines a function to retrieve the most similar documents from the FAISS vector store.
#
# Within the `score_chunks` function, an empty scored list is initialized. For each chunk, the `scoring_prompt_template` is formatted with the specific query and chunk. This formatted prompt is then sent to the LLM and the response is stripped. The function attempts to extract the integer score (a binary score if simplified to just relevant or not relevant) by identifying the "Score:" line in the model's response. The chunk along with its parsed or defaulted score is then added to the scored list. This part of the system acts as a retrieval evaluator or grader — a critical safeguard for legal answers, where irrelevant context can produce misleading conclusions.
#
# The function `retrieve_from_vectorstore` implements a `vectorstore.similarity_search` to find the 8 most relevant document chunks based on the query and retrieves the `page_content` from these retrieved LangChain Document objects.
#
# This step builds the conceptual scaffolding for the Corrective RAG system, so that both the LLM will evaluate context and how to retrieve knowledge from both internal and external knowledge sources.

# %% [markdown]
# ### Step 8. Implement the Corrective RAG logic
#
# **Initial retrieval:** The function scans the vector store of the PDF.
#
# **Context scoring:** The PDF chunks that have been retrieved are context scored according to relevancy.
#
# **Fallback to tavily:** If not enough relevant context from the PDF, it queries Tavily (web search).
#
# **Source verification:** An LLM-powered step checks if the Tavily results are relevant to a private policy before using them. This prevents misleading answers from public health programs.
#
# **Query rewriting and second tavily search:** If it's still no good context, it rewrites the query and tries Tavily search again.
#
# **Final decision:** If there is any relevant context, it is sent to the LLM with a (strict) prompt to create the answer. If there is no relevant context after all viable attempts, it sends a very polite denial.

# %%
# Implement the Corrective RAG Logic

MIN_CONTEXT_LENGTH = 100 # Adjust this based on how much minimal context you expect for a partial answer
SIMILARITY_THRESHOLD = 3 # Only scores >= 3 used for vector store chunks

def corrective_rag(query: str, policy_context_keywords: list = None):
    """
    Executes the Corrective RAG process to answer insurance queries.

    Args:
        query (str): The user's question.
        policy_context_keywords (list, optional): Keywords related to the specific policy
                                                  (e.g., ["Super Star Health", "Care Health Insurance"]).
                                                  Used to make external searches more specific. Defaults to None.
    Returns:
        str: The final answer generated by the LLM or a predefined refusal.
    """
    retrieved_context_pieces = [] # To store all relevant pieces found throughout the process

    # Initial vector search & Scoring (from your PDF)
    chunks_from_vectorstore = retrieve_from_vectorstore(query)
    scored_chunks_vector = score_chunks(chunks_from_vectorstore, query)
    good_chunks_vector = [chunk for chunk, score in scored_chunks_vector if score >= SIMILARITY_THRESHOLD]
    retrieved_context_pieces.extend(good_chunks_vector)

    current_context = "\n\n".join(retrieved_context_pieces)
    print(f" Context length after initial vector scoring: {len(current_context)}")

    # Prepare specific query for Tavily by optionally adding policy keywords
    tavily_search_query = query
    if policy_context_keywords:
        tavily_search_query = f"{query} {' '.join(policy_context_keywords)}"

    # Fallback: Tavily direct search (only if current context is too short from vector store)
    if len(current_context) < MIN_CONTEXT_LENGTH:
        print(f" Context too short from internal docs, trying Tavily direct with query: '{tavily_search_query}'...")
        tavily_context_direct = tavily_tool._run(tavily_search_query)

        if tavily_context_direct:
            # --- NEW STEP: Verify Tavily Context Source ---
            # Ask the LLM if the Tavily result seems to be from a private policy context or a public program
            verification_prompt = CONTEXT_SOURCE_VERIFICATION_PROMPT.format(context=tavily_context_direct)
            is_relevant_source = llm(verification_prompt).strip().upper()

            if is_relevant_source == "YES":
                retrieved_context_pieces.append(tavily_context_direct)
                current_context = "\n\n".join(retrieved_context_pieces) # Re-combine all good context
                print(f" Context length after Tavily direct (verified and added): {len(current_context)}")
            else:
                print(f" Tavily direct context source rejected (e.g., public program): {tavily_context_direct[:100]}...")
                # Context is NOT added, so it remains short and triggers the next fallback or final refusal

    # Fallback: Rewrite query + Tavily (only if context is still too short after direct Tavily)
    if len(current_context) < MIN_CONTEXT_LENGTH:
        print(" Context still too short, rewriting query and trying Tavily...")
        rewrite_prompt = rewrite_prompt_template.format(query=query)
        improved_query = llm(rewrite_prompt).strip()

        # Add policy keywords to the rewritten query too
        if policy_context_keywords:
            improved_query = f"{improved_query} {' '.join(policy_context_keywords)}"

        print(f" Rewritten query: '{improved_query}'")
        tavily_context_rewritten = tavily_tool._run(improved_query)

        if tavily_context_rewritten:
            # --- NEW STEP: Verify Rewritten Tavily Context Source ---
            verification_prompt = CONTEXT_SOURCE_VERIFICATION_PROMPT.format(context=tavily_context_rewritten)
            is_relevant_source = llm(verification_prompt).strip().upper()

            if is_relevant_source == "YES":
                retrieved_context_pieces.append(tavily_context_rewritten)
                current_context = "\n\n".join(retrieved_context_pieces) # Re-combine all good context
                print(f" Context length after rewritten Tavily (verified and added): {len(current_context)}")
            else:
                print(f" Tavily rewritten context source rejected (e.g., public program): {tavily_context_rewritten[:100]}...")

    # --- Final Decision Point ---
    # Now, `current_context` holds ALL the "good" and "verified" context we managed to gather.
    # The decision to call the LLM for an answer or give a hard refusal is based on `current_context`'s length.

    # Final check for absolutely no good context
    # This triggers only if *no* relevant internal or external context was found or verified.
    if len(current_context.strip()) == 0:
        print(" No good context found after all attempts. Returning absolute fallback.")
        return (
            "Based on the information provided, there is no clear mention of this specific detail "
            "in the policy documents available."
        )

    # If we have *any* context (even if short), pass it to the LLM to process
    # The LLM will then decide how to phrase the answer based on its prompt instructions
    # (exact, partial, or full refusal if context is irrelevant or insufficient based on its own reasoning).
    final_prompt = (
        f"You are a careful insurance expert.\n"
        f"Use ONLY the following context to answer the user's question. If the context is too short "
        f"or does not contain the answer, you must indicate that.\n"
        f"Context:\n```\n{current_context}\n```\n\n" # Pass the gathered context
        f"User's Question: {query}\n\n" # Pass the original query for the LLM's reference
        f"NEVER add new details that are not in the context word-for-word.\n"
        f"If the context clearly says the answer, give it exactly as written in the context, but in prose.\n"
        f"If the context does not mention the topic at all, or the answer is not in the context, say:\n"
        f"\"I'm sorry, but this information is not available in the provided policy details.\"\n"
        f"If the context partially mentions the topic but does not directly answer the specific question (e.g., mentions 'dental' but not 'wisdom tooth removal'), reply like this:\n"
        f"\"Based on the information provided, here’s what is known: [quote relevant details from the context related to the broad topic.] "
        f"There is no clear mention of the specific detail asked about.\"\n"
        f"Do NOT assume. Do NOT make up extra information.\n"
        f"Do NOT generate extra questions or conversational filler.\n"
        f"Final Answer:"
    )

    return llm(final_prompt)

print(" Corrective RAG logic implemented.")

# %% [markdown]
# The first pass of the `policy_context_keywords` parameter allows you to add specific terms from your policy (for example, its name, insurer) to help narrow searches for Tavily.
#
# `MIN_CONTEXT_LENGTH:` defines the minimum acceptable length of retrieved context.
#
# `SIMILARITY_THRESHOLD:` defines the minimum relevance score a chunk must have to be considered "good."
#
# `def corrective_rag(...):` defines the main function that orchestrates the entire Corrective RAG [workflow](https://www.ibm.com/think/topics/workflow).
#
# The `corrective_rag` function begins by creating `retrieved_context_pieces` to gather relevant context. It first fetches and scores `chunks_from_vectorstore` from the PDF vector store based on the query, then `scored_chunks_vector` evaluates their relevance using the language model. Only `good_chunks_vector` that meet the `SIMILARITY_THRESHOLD` are kept. The `current_context` is then compiled from these pieces.
#
# If the current_context is below `MIN_CONTEXT_LENGTH`, the system attempts a web search. It constructs `tavily_search_query`, potentially incorporating `policy_context_keywords`. A direct search (`tavily_context_direct`) is performed. Crucially, a `verification_prompt` is created and sent to the LLM to determine if the web search result (`is_relevant_source`)  is from a private policy rather than a public program. If it's YES, the context is added.
#
# If the context remains insufficient, the system prepares to rewrite the query. It uses `rewrite_prompt` to get an `improved_query` from the LLM, then performs a second web search (`tavily_context_rewritten`). This new context also undergoes the same source verification.
#
# Finally, `if len(current_context.strip()) == 0:` is a last check. If no relevant context is found after all attempts, a predefined refusal message is returned. Otherwise, a `final_prompt` is created with all the verified context and sent to the language model to generate it's final answer.
#
# The entire `corrective_rag` function handles the staged retrieving, scoring and verifying functions of Corrective RAG in detail. It allows for constant updating of the knowledge base and knowledge stream, and brings the benefit of robustness and contextually aware answers.

# %% [markdown]
# ### Step 9. Test the system
#
# Finally, execute your `corrective_rag` function with a sample query. It's crucial to provide `policy_context_keywords` that are specific to your PDF document. These keywords will help the Tavily web search become more relevant to your actual policy, preventing general or public health program information from polluting your context.
#
# Observe the print statements for context length and verification results to understand the flow of information.

# %%
query = "How does the policy cover for In-Patient Hospitalisation?"
result = corrective_rag(query)

print("\n FINAL ANSWER:\n")
print(result)

# %%
query = "Does this insurance cover hospitalization for COVID-19 and what are the exclusions?"
result = corrective_rag(query)

print("\n FINAL ANSWER:\n")
print(result)

# %% [markdown]
# `policy_specific_keywords = ["Super Star Health", "Care Health Insurance"]:` this defines a list of keywords which are relevant to uploaded insurance policy, helping to narrow down web search results.
#
# `query = "...":` defines the particular question a user might ask.
#
# `result = corrective_rag(query, policy_context_keywords=policy_specific_keywords):` calls the main corrective_rag function and passes the user's query and policy-specific keywords to begin the entire RAG process.
#
# `print("\n FINAL ANSWER (...)"):` displays a clear header before printing the generated answer.
#
# `print(result):` this outputs the final answer returned by the corrective_rag system.
#
# This step shows how to invoke the complete Corrective RAG system with a sample query and keywords, demonstrating its end-to-end functionality in a real-world scenario.

# %% [markdown]
# ## Key takeaways
#
# The Corrective RAG implemented fully coordinated an internal PDF knowledge base with external service (Tavily) to retrieve comprehensive information for complex requests.
#
# It accurately evaluated and filtered through retrieved context using LLM based scoring and critical source verification to ensure valid and reliable information is being used.
#
# The system demonstrated the ability to improve external search by intelligently rewriting user queries to request more targeted and higher quality information.
#
# Using constrained generation, a reliable and contextually accurate answer was commonly generated and the system politely refused to answer if there was not enough known verified information.
#
# This example demonstrated how LangChain and IBM Granite LLMs on Watsonx can be used to develop powerful and trustworthy AI-based applications in sensitive domains such as asking questions about insurance policies.
